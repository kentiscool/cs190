# %%
import os
import librosa
import soundfile as sf
from librosa.core import load, stft, istft, magphase
from librosa import to_mono, resample
from config import *
from concurrent.futures import ThreadPoolExecutor   
from time import time
import asyncio
import numpy as np
from multiprocessing import cpu_count
import musdb
from pathlib import Path
import IPython
from tqdm import tqdm
import tensorflow as tf
from config import *
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Conv2D, Dropout, BatchNormalization, LeakyReLU, Conv2DTranspose as Deconv2D, Activation, Concatenate

# %%
SAMPLE_RATE=44
WINDOW_SIZE=1024
HOP_LENGTH=768

PATCH_SIZE=128
EPOCH = 20 # test
BATCH = 16
SAMPLE_STRIDE = 10

# %%
def load_as_spect(wav):
    # 1024 point STFT with 75% overlap, as state in the paper
    spectrogram = stft(wav, n_fft=1024)
    mag, phase = magphase(spectrogram)
    return np.log(1 + mag.astype(np.float32)), phase

# %%
mus = musdb.DB(root="./data/raw")

# %%
def save_as_npz(track, dir_name):
    mono_vocal, mono_mix = to_mono(np.transpose(track.targets['vocals'].audio)), to_mono(np.transpose(track.audio))
    downsampled_vocal, downsampled_mix = resample(mono_vocal, track.rate, 8192), resample(mono_mixture, track.rate, 8192)
    vocal_mag, vocal_phase = load_as_spect(downsampled_vocal)
    mix_mag, mix_phase = load_as_spect(downsampled_mix)
    if not os.path.exists(dir_name + track.name):
        os.mknod(dir_name + track.name)
    np.savez(dir_name + track.name, vocal_mag=vocal, vocal_phase=vocal_phase, mix_mag=mix_mag, mix_phase=mix_phase) 

def process(subset):
    raw_data = mus.load_mus_tracks(subsets=subset)
    Path("./data/processed/" + subset + "/").mkdir(parents=True, exist_ok=True)
    
    with ThreadPoolExecutor(max_workers=cpu_count() * 2) as pool:
        for track in tqdm(raw_data):
            pool.submit(save_as_npz, track, "./data/processed/" + subset + "/")

# %%
process("train")
# Out:
# 100%|██████████| 100/100 [00:30<00:00,  3.32it/s]

# %%
def create_model():
    input = Input((512, 128, 1))
    
    # INPUT BACKBONE
    
    # (1, 0) ConvGLU
    X_10_a = Conv2D(16, 5, strides=2, padding='same', name="X_10_a")(input)
    X_10_b = Activation(tf.nn.sigmoid)(Conv2D(16, 5, strides=2, padding='same', name="X_10_b")(input))
    X_10 = BatchNormalization()(LeakyReLU(name="X_10", alpha=0.2)(tf.multiply(X_10_a, X_10_b)))
    
    # (2, 0) ConvGLU
    X_20_a = Conv2D(32, 5, strides=2, padding='same', name="X_20_a")(X_10)
    X_20_b = Activation(tf.nn.sigmoid)(Conv2D(32, 5, strides=2, padding='same', name="X_20_b")(X_10))
    X_20 = BatchNormalization()(LeakyReLU(name="X_20", alpha=0.2)(tf.multiply(X_20_a, X_20_b)))
    
    # (3, 0) ConvGLU
    X_30_a = Conv2D(64, 5, strides=2, padding='same', name="X_30_a")(X_20)
    X_30_b = Activation(tf.nn.sigmoid)(Conv2D(64, 5, strides=2, padding='same', name="X_30_b")(X_20))
    X_30 = BatchNormalization()(LeakyReLU(name="X_30", alpha=0.2)(tf.multiply(X_30_a, X_30_b)))
    
    # (4, 0) ConvGLU
    X_40_a = Conv2D(128, 5, strides=2, padding='same', name="X_40_a")(X_30)
    X_40_b = Activation(tf.nn.sigmoid)(Conv2D(128, 5, strides=2, padding='same', name="X_40_b")(X_30))
    X_40 = BatchNormalization()(LeakyReLU(name="X_40", alpha=0.2)(tf.multiply(X_40_a, X_40_b)))
    
    # (5, 0) ConvGLU
    X_50_a = Conv2D(256, 5, strides=2, padding='same', name="X_50_a")(X_40)
    X_50_b = Activation(tf.nn.sigmoid)(Conv2D(256, 5, strides=2, padding='same', name="X_50_b")(X_40))
    X_50 = BatchNormalization()(LeakyReLU(name="X_50", alpha=0.2)(tf.multiply(X_50_a, X_50_b)))
    
    # (6, 0) ConvGLU
    X_60_a = Conv2D(512, 5, strides=2, padding='same', name="X_60_a")(X_50)
    X_60_b = Activation(tf.nn.sigmoid)(Conv2D(512, 5, strides=2, padding='same', name="X_60_b")(X_50))
    X_60 = BatchNormalization()(LeakyReLU(name="X_60", alpha=0.2)(tf.multiply(X_60_a, X_60_b)))
    
    # NESTED
    
    # (4, 1) Deconv & Concatenate
    X_41_a = Deconv2D(128, 5, strides=2, padding='same', name="X_41_a")(X_50)
    X_41_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_41_a))
    X_41 = Concatenate(axis=3, name="X_41")([X_40, X_41_b])
    
    # (3, 1) Deconv & Concatenate
    X_31_a = Deconv2D(64, 5, strides=2, padding='same', name="X_31_a")(X_40)
    X_31_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_31_a))
    X_31 = Concatenate(axis=3, name="X_31")([X_30, X_31_b])
    
    # (3, 2) Deconv & Concatenate
    X_32_a = Deconv2D(64, 5, strides=2, padding='same', name="X_32_a")(X_41)
    X_32_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_32_a))
    X_32 = Concatenate(axis=3, name="X_32")([X_31, X_32_b])
    
    # (2, 1) Deconv & Concatenate
    X_21_a = Deconv2D(32, 5, strides=2, padding='same', name="X_21_a")(X_30)
    X_21_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_21_a))
    X_21 = Concatenate(axis=3, name="X_21")([X_20, X_21_b])
    
    # (2, 2) Deconv & Concatenate
    X_22_a = Deconv2D(32, 5, strides=2, padding='same', name="X_22_a")(X_31)
    X_22_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_22_a))
    X_22 = Concatenate(axis=3, name="X_22")([X_21, X_22_b])
    
    # (2, 3) Deconv & Concatenate
    X_23_a = Deconv2D(32, 5, strides=2, padding='same', name="X_23_a")(X_32)
    X_23_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_23_a))
    X_23 = Concatenate(axis=3, name="X_23")([X_22, X_23_b])
    
    # (1, 1) Deconv & Concatenate
    X_11_a = Deconv2D(16, 5, strides=2, padding='same', name="X_11_a")(X_20)
    X_11_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_11_a))
    X_11 = Concatenate(axis=3, name="X_11")([X_10, X_11_b])
    
    # (1, 2) Deconv & Concatenate
    X_12_a = Deconv2D(16, 5, strides=2, padding='same', name="X_12_a")(X_21)
    X_12_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_12_a))
    X_12 = Concatenate(axis=3, name="X_12")([X_11, X_12_b])
    
    # (1, 3) Deconv & Concatenate
    X_13_a = Deconv2D(16, 5, strides=2, padding='same', name="X_13_a")(X_22)
    X_13_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_13_a))
    X_13 = Concatenate(axis=3, name="X_13")([X_12, X_13_b])

    # (1, 4) Deconv & Concatenate
    X_14_a = Deconv2D(16, 5, strides=2, padding='same', name="X_14_a")(X_23)
    X_14_b = BatchNormalization()(LeakyReLU(alpha=0.2)(X_14_a))
    X_14 = Concatenate(axis=3, name="X_14")([X_13, X_14_b])
    
    # OUTPUT BACKBONE
    
    # (5, 1) DeconvGLU & Concatenate
    X_51_a = Deconv2D(256, 5, strides=2, padding='same', name="X_51_a")(X_60)
    X_51_b = Activation(tf.nn.sigmoid)(Deconv2D(256, 5, strides=2, padding='same', name="X_51_b")(X_60))
    X_51_c = BatchNormalization()(LeakyReLU(name="X_51_c", alpha=0.2)(tf.multiply(X_51_a, X_51_b)))
    X_51 = Concatenate(axis=3, name="X_51")([X_50, X_51_c])
    
    # (4, 2) DeconvGLU & Concatenate
    X_42_a = Deconv2D(128, 5, strides=2, padding='same', name="X_42_a")(X_51)
    X_42_b = Activation(tf.nn.sigmoid)(Deconv2D(128, 5, strides=2, padding='same', name="X_42_b")(X_51))
    X_42_c = BatchNormalization()(LeakyReLU(name="X_42_c", alpha=0.2)(tf.multiply(X_42_a, X_42_b)))
    X_42 = Concatenate(axis=3, name="X_42")([X_41, X_42_c])

    # (3, 3) DeconvGLU & Concatenate
    X_33_a = Deconv2D(64, 5, strides=2, padding='same', name="X_33_a")(X_42)
    X_33_b = Activation(tf.nn.sigmoid)(Deconv2D(64, 5, strides=2, padding='same', name="X_33_b")(X_42))
    X_33_c = BatchNormalization()(LeakyReLU(name="X_33_c", alpha=0.2)(tf.multiply(X_33_a, X_33_b)))
    X_33 = Concatenate(axis=3, name="X_33")([X_32, X_33_c])
    
    # (2, 4) DeconvGLU & Concatenate
    X_24_a = Deconv2D(32, 5, strides=2, padding='same', name="X_24_a")(X_33)
    X_24_b = Activation(tf.nn.sigmoid)(Deconv2D(32, 5, strides=2, padding='same', name="X_24_b")(X_33))
    X_24_c = BatchNormalization()(LeakyReLU(name="X_24_c", alpha=0.2)(tf.multiply(X_24_a, X_24_b)))
    X_24 = Concatenate(axis=3, name="X_24")([X_23, X_24_c])
    
    # (1, 5) DeconvGLU & Concatenate
    X_15_a = Deconv2D(16, 5, strides=2, padding='same', name="X_15_a")(X_24)
    X_15_b = Activation(tf.nn.sigmoid)(Deconv2D(16, 5, strides=2, padding='same', name="X_15_b")(X_24))
    X_15_c = BatchNormalization()(LeakyReLU(name="X_15_c", alpha=0.2)(tf.multiply(X_15_a, X_15_b)))
    X_15 = Concatenate(axis=3, name="X_15")([X_14, X_15_c])
    
    # U-NET OUTPUT
    
    # (0, 6) DeconvGLU & Concatenate
    X_06_a = Deconv2D(1, 5, strides=2, padding='same', name="X_06_a")(X_15)
    X_06_b = Activation(tf.nn.sigmoid)(Deconv2D(1, 5, strides=2, padding='same', name="X_06_b")(X_15))
    X_06 = BatchNormalization()(LeakyReLU(name="X_06", alpha=0.2)(tf.multiply(X_06_a, X_06_b)))
    
    # Difference Mask Layer
    
    # M1
    M_1_a = Concatenate(axis=3, name="M_1_a")([input, X_06])
    M_1 = Activation(tf.nn.sigmoid)(Conv2D(1, 2, strides=1, padding='same', name="M_1")(M_1_a))
    
    output = tf.multiply(M_1, input)
    
    model = Model(inputs=input, outputs=output)
    model.summary()
    return model
create_model()
# Out:
# Model: "model_89"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_117 (InputLayer)          [(None, 512, 128, 1) 0
# __________________________________________________________________________________________________
# X_10_b (Conv2D)                 (None, 256, 64, 16)  416         input_117[0][0]
# __________________________________________________________________________________________________
# X_10_a (Conv2D)                 (None, 256, 64, 16)  416         input_117[0][0]
# __________________________________________________________________________________________________
# activation_846 (Activation)     (None, 256, 64, 16)  0           X_10_b[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_790 (TensorFlow [(None, 256, 64, 16) 0           X_10_a[0][0]
#                                                                  activation_846[0][0]
# __________________________________________________________________________________________________
# X_10 (LeakyReLU)                (None, 256, 64, 16)  0           tf_op_layer_Mul_790[0][0]
# __________________________________________________________________________________________________
# batch_normalization_553 (BatchN (None, 256, 64, 16)  64          X_10[0][0]
# __________________________________________________________________________________________________
# X_20_b (Conv2D)                 (None, 128, 32, 32)  12832       batch_normalization_553[0][0]
# __________________________________________________________________________________________________
# X_20_a (Conv2D)                 (None, 128, 32, 32)  12832       batch_normalization_553[0][0]
# __________________________________________________________________________________________________
# activation_847 (Activation)     (None, 128, 32, 32)  0           X_20_b[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_791 (TensorFlow [(None, 128, 32, 32) 0           X_20_a[0][0]
#                                                                  activation_847[0][0]
# __________________________________________________________________________________________________
# X_20 (LeakyReLU)                (None, 128, 32, 32)  0           tf_op_layer_Mul_791[0][0]
# __________________________________________________________________________________________________
# batch_normalization_554 (BatchN (None, 128, 32, 32)  128         X_20[0][0]
# __________________________________________________________________________________________________
# X_30_b (Conv2D)                 (None, 64, 16, 64)   51264       batch_normalization_554[0][0]
# __________________________________________________________________________________________________
# X_30_a (Conv2D)                 (None, 64, 16, 64)   51264       batch_normalization_554[0][0]
# __________________________________________________________________________________________________
# activation_848 (Activation)     (None, 64, 16, 64)   0           X_30_b[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_792 (TensorFlow [(None, 64, 16, 64)] 0           X_30_a[0][0]
#                                                                  activation_848[0][0]
# __________________________________________________________________________________________________
# X_30 (LeakyReLU)                (None, 64, 16, 64)   0           tf_op_layer_Mul_792[0][0]
# __________________________________________________________________________________________________
# batch_normalization_555 (BatchN (None, 64, 16, 64)   256         X_30[0][0]
# __________________________________________________________________________________________________
# X_40_b (Conv2D)                 (None, 32, 8, 128)   204928      batch_normalization_555[0][0]
# __________________________________________________________________________________________________
# X_40_a (Conv2D)                 (None, 32, 8, 128)   204928      batch_normalization_555[0][0]
# __________________________________________________________________________________________________
# activation_849 (Activation)     (None, 32, 8, 128)   0           X_40_b[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_793 (TensorFlow [(None, 32, 8, 128)] 0           X_40_a[0][0]
#                                                                  activation_849[0][0]
# __________________________________________________________________________________________________
# X_40 (LeakyReLU)                (None, 32, 8, 128)   0           tf_op_layer_Mul_793[0][0]
# __________________________________________________________________________________________________
# batch_normalization_556 (BatchN (None, 32, 8, 128)   512         X_40[0][0]
# __________________________________________________________________________________________________
# X_50_b (Conv2D)                 (None, 16, 4, 256)   819456      batch_normalization_556[0][0]
# __________________________________________________________________________________________________
# X_50_a (Conv2D)                 (None, 16, 4, 256)   819456      batch_normalization_556[0][0]
# __________________________________________________________________________________________________
# activation_850 (Activation)     (None, 16, 4, 256)   0           X_50_b[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_794 (TensorFlow [(None, 16, 4, 256)] 0           X_50_a[0][0]
#                                                                  activation_850[0][0]
# __________________________________________________________________________________________________
# X_50 (LeakyReLU)                (None, 16, 4, 256)   0           tf_op_layer_Mul_794[0][0]
# __________________________________________________________________________________________________
# batch_normalization_557 (BatchN (None, 16, 4, 256)   1024        X_50[0][0]
# __________________________________________________________________________________________________
# X_60_b (Conv2D)                 (None, 8, 2, 512)    3277312     batch_normalization_557[0][0]
# __________________________________________________________________________________________________
# X_60_a (Conv2D)                 (None, 8, 2, 512)    3277312     batch_normalization_557[0][0]
# __________________________________________________________________________________________________
# activation_851 (Activation)     (None, 8, 2, 512)    0           X_60_b[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_795 (TensorFlow [(None, 8, 2, 512)]  0           X_60_a[0][0]
#                                                                  activation_851[0][0]
# __________________________________________________________________________________________________
# X_60 (LeakyReLU)                (None, 8, 2, 512)    0           tf_op_layer_Mul_795[0][0]
# __________________________________________________________________________________________________
# batch_normalization_558 (BatchN (None, 8, 2, 512)    2048        X_60[0][0]
# __________________________________________________________________________________________________
# X_51_b (Conv2DTranspose)        (None, 16, 4, 256)   3277056     batch_normalization_558[0][0]
# __________________________________________________________________________________________________
# X_51_a (Conv2DTranspose)        (None, 16, 4, 256)   3277056     batch_normalization_558[0][0]
# __________________________________________________________________________________________________
# activation_852 (Activation)     (None, 16, 4, 256)   0           X_51_b[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_796 (TensorFlow [(None, 16, 4, 256)] 0           X_51_a[0][0]
#                                                                  activation_852[0][0]
# __________________________________________________________________________________________________
# X_51_c (LeakyReLU)              (None, 16, 4, 256)   0           tf_op_layer_Mul_796[0][0]
# __________________________________________________________________________________________________
# batch_normalization_569 (BatchN (None, 16, 4, 256)   1024        X_51_c[0][0]
# __________________________________________________________________________________________________
# X_51 (Concatenate)              (None, 16, 4, 512)   0           batch_normalization_557[0][0]
#                                                                  batch_normalization_569[0][0]
# __________________________________________________________________________________________________
# X_42_b (Conv2DTranspose)        (None, 32, 8, 128)   1638528     X_51[0][0]
# __________________________________________________________________________________________________
# X_41_a (Conv2DTranspose)        (None, 32, 8, 128)   819328      batch_normalization_557[0][0]
# __________________________________________________________________________________________________
# X_42_a (Conv2DTranspose)        (None, 32, 8, 128)   1638528     X_51[0][0]
# __________________________________________________________________________________________________
# activation_853 (Activation)     (None, 32, 8, 128)   0           X_42_b[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_303 (LeakyReLU)     (None, 32, 8, 128)   0           X_41_a[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_797 (TensorFlow [(None, 32, 8, 128)] 0           X_42_a[0][0]
#                                                                  activation_853[0][0]
# __________________________________________________________________________________________________
# batch_normalization_559 (BatchN (None, 32, 8, 128)   512         leaky_re_lu_303[0][0]
# __________________________________________________________________________________________________
# X_42_c (LeakyReLU)              (None, 32, 8, 128)   0           tf_op_layer_Mul_797[0][0]
# __________________________________________________________________________________________________
# X_41 (Concatenate)              (None, 32, 8, 256)   0           batch_normalization_556[0][0]
#                                                                  batch_normalization_559[0][0]
# __________________________________________________________________________________________________
# batch_normalization_570 (BatchN (None, 32, 8, 128)   512         X_42_c[0][0]
# __________________________________________________________________________________________________
# X_42 (Concatenate)              (None, 32, 8, 384)   0           X_41[0][0]
#                                                                  batch_normalization_570[0][0]
# __________________________________________________________________________________________________
# X_31_a (Conv2DTranspose)        (None, 64, 16, 64)   204864      batch_normalization_556[0][0]
# __________________________________________________________________________________________________
# X_33_b (Conv2DTranspose)        (None, 64, 16, 64)   614464      X_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_304 (LeakyReLU)     (None, 64, 16, 64)   0           X_31_a[0][0]
# __________________________________________________________________________________________________
# X_32_a (Conv2DTranspose)        (None, 64, 16, 64)   409664      X_41[0][0]
# __________________________________________________________________________________________________
# X_33_a (Conv2DTranspose)        (None, 64, 16, 64)   614464      X_42[0][0]
# __________________________________________________________________________________________________
# activation_854 (Activation)     (None, 64, 16, 64)   0           X_33_b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_560 (BatchN (None, 64, 16, 64)   256         leaky_re_lu_304[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_305 (LeakyReLU)     (None, 64, 16, 64)   0           X_32_a[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_798 (TensorFlow [(None, 64, 16, 64)] 0           X_33_a[0][0]
#                                                                  activation_854[0][0]
# __________________________________________________________________________________________________
# X_31 (Concatenate)              (None, 64, 16, 128)  0           batch_normalization_555[0][0]
#                                                                  batch_normalization_560[0][0]
# __________________________________________________________________________________________________
# batch_normalization_561 (BatchN (None, 64, 16, 64)   256         leaky_re_lu_305[0][0]
# __________________________________________________________________________________________________
# X_33_c (LeakyReLU)              (None, 64, 16, 64)   0           tf_op_layer_Mul_798[0][0]
# __________________________________________________________________________________________________
# X_32 (Concatenate)              (None, 64, 16, 192)  0           X_31[0][0]
#                                                                  batch_normalization_561[0][0]
# __________________________________________________________________________________________________
# batch_normalization_571 (BatchN (None, 64, 16, 64)   256         X_33_c[0][0]
# __________________________________________________________________________________________________
# X_21_a (Conv2DTranspose)        (None, 128, 32, 32)  51232       batch_normalization_555[0][0]
# __________________________________________________________________________________________________
# X_33 (Concatenate)              (None, 64, 16, 256)  0           X_32[0][0]
#                                                                  batch_normalization_571[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_306 (LeakyReLU)     (None, 128, 32, 32)  0           X_21_a[0][0]
# __________________________________________________________________________________________________
# X_22_a (Conv2DTranspose)        (None, 128, 32, 32)  102432      X_31[0][0]
# __________________________________________________________________________________________________
# X_24_b (Conv2DTranspose)        (None, 128, 32, 32)  204832      X_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_562 (BatchN (None, 128, 32, 32)  128         leaky_re_lu_306[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_307 (LeakyReLU)     (None, 128, 32, 32)  0           X_22_a[0][0]
# __________________________________________________________________________________________________
# X_23_a (Conv2DTranspose)        (None, 128, 32, 32)  153632      X_32[0][0]
# __________________________________________________________________________________________________
# X_24_a (Conv2DTranspose)        (None, 128, 32, 32)  204832      X_33[0][0]
# __________________________________________________________________________________________________
# activation_855 (Activation)     (None, 128, 32, 32)  0           X_24_b[0][0]
# __________________________________________________________________________________________________
# X_21 (Concatenate)              (None, 128, 32, 64)  0           batch_normalization_554[0][0]
#                                                                  batch_normalization_562[0][0]
# __________________________________________________________________________________________________
# batch_normalization_563 (BatchN (None, 128, 32, 32)  128         leaky_re_lu_307[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_308 (LeakyReLU)     (None, 128, 32, 32)  0           X_23_a[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_799 (TensorFlow [(None, 128, 32, 32) 0           X_24_a[0][0]
#                                                                  activation_855[0][0]
# __________________________________________________________________________________________________
# X_22 (Concatenate)              (None, 128, 32, 96)  0           X_21[0][0]
#                                                                  batch_normalization_563[0][0]
# __________________________________________________________________________________________________
# batch_normalization_564 (BatchN (None, 128, 32, 32)  128         leaky_re_lu_308[0][0]
# __________________________________________________________________________________________________
# X_24_c (LeakyReLU)              (None, 128, 32, 32)  0           tf_op_layer_Mul_799[0][0]
# __________________________________________________________________________________________________
# X_11_a (Conv2DTranspose)        (None, 256, 64, 16)  12816       batch_normalization_554[0][0]
# __________________________________________________________________________________________________
# X_23 (Concatenate)              (None, 128, 32, 128) 0           X_22[0][0]
#                                                                  batch_normalization_564[0][0]
# __________________________________________________________________________________________________
# batch_normalization_572 (BatchN (None, 128, 32, 32)  128         X_24_c[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_309 (LeakyReLU)     (None, 256, 64, 16)  0           X_11_a[0][0]
# __________________________________________________________________________________________________
# X_12_a (Conv2DTranspose)        (None, 256, 64, 16)  25616       X_21[0][0]
# __________________________________________________________________________________________________
# X_24 (Concatenate)              (None, 128, 32, 160) 0           X_23[0][0]
#                                                                  batch_normalization_572[0][0]
# __________________________________________________________________________________________________
# batch_normalization_565 (BatchN (None, 256, 64, 16)  64          leaky_re_lu_309[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_310 (LeakyReLU)     (None, 256, 64, 16)  0           X_12_a[0][0]
# __________________________________________________________________________________________________
# X_13_a (Conv2DTranspose)        (None, 256, 64, 16)  38416       X_22[0][0]
# __________________________________________________________________________________________________
# X_15_b (Conv2DTranspose)        (None, 256, 64, 16)  64016       X_24[0][0]
# __________________________________________________________________________________________________
# X_11 (Concatenate)              (None, 256, 64, 32)  0           batch_normalization_553[0][0]
#                                                                  batch_normalization_565[0][0]
# __________________________________________________________________________________________________
# batch_normalization_566 (BatchN (None, 256, 64, 16)  64          leaky_re_lu_310[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_311 (LeakyReLU)     (None, 256, 64, 16)  0           X_13_a[0][0]
# __________________________________________________________________________________________________
# X_14_a (Conv2DTranspose)        (None, 256, 64, 16)  51216       X_23[0][0]
# __________________________________________________________________________________________________
# X_15_a (Conv2DTranspose)        (None, 256, 64, 16)  64016       X_24[0][0]
# __________________________________________________________________________________________________
# activation_856 (Activation)     (None, 256, 64, 16)  0           X_15_b[0][0]
# __________________________________________________________________________________________________
# X_12 (Concatenate)              (None, 256, 64, 48)  0           X_11[0][0]
#                                                                  batch_normalization_566[0][0]
# __________________________________________________________________________________________________
# batch_normalization_567 (BatchN (None, 256, 64, 16)  64          leaky_re_lu_311[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_312 (LeakyReLU)     (None, 256, 64, 16)  0           X_14_a[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_800 (TensorFlow [(None, 256, 64, 16) 0           X_15_a[0][0]
#                                                                  activation_856[0][0]
# __________________________________________________________________________________________________
# X_13 (Concatenate)              (None, 256, 64, 64)  0           X_12[0][0]
#                                                                  batch_normalization_567[0][0]
# __________________________________________________________________________________________________
# batch_normalization_568 (BatchN (None, 256, 64, 16)  64          leaky_re_lu_312[0][0]
# __________________________________________________________________________________________________
# X_15_c (LeakyReLU)              (None, 256, 64, 16)  0           tf_op_layer_Mul_800[0][0]
# __________________________________________________________________________________________________
# X_14 (Concatenate)              (None, 256, 64, 80)  0           X_13[0][0]
#                                                                  batch_normalization_568[0][0]
# __________________________________________________________________________________________________
# batch_normalization_573 (BatchN (None, 256, 64, 16)  64          X_15_c[0][0]
# __________________________________________________________________________________________________
# X_15 (Concatenate)              (None, 256, 64, 96)  0           X_14[0][0]
#                                                                  batch_normalization_573[0][0]
# __________________________________________________________________________________________________
# X_06_b (Conv2DTranspose)        (None, 512, 128, 1)  2401        X_15[0][0]
# __________________________________________________________________________________________________
# X_06_a (Conv2DTranspose)        (None, 512, 128, 1)  2401        X_15[0][0]
# __________________________________________________________________________________________________
# activation_857 (Activation)     (None, 512, 128, 1)  0           X_06_b[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_801 (TensorFlow [(None, 512, 128, 1) 0           X_06_a[0][0]
#                                                                  activation_857[0][0]
# __________________________________________________________________________________________________
# X_06 (LeakyReLU)                (None, 512, 128, 1)  0           tf_op_layer_Mul_801[0][0]
# __________________________________________________________________________________________________
# batch_normalization_574 (BatchN (None, 512, 128, 1)  4           X_06[0][0]
# __________________________________________________________________________________________________
# M_1_a (Concatenate)             (None, 512, 128, 2)  0           input_117[0][0]
#                                                                  batch_normalization_574[0][0]
# __________________________________________________________________________________________________
# M_1 (Conv2D)                    (None, 512, 128, 1)  9           M_1_a[0][0]
# __________________________________________________________________________________________________
# activation_858 (Activation)     (None, 512, 128, 1)  0           M_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_802 (TensorFlow [(None, 512, 128, 1) 0           activation_858[0][0]
#                                                                  input_117[0][0]
# ==================================================================================================
# Total params: 22,211,919
# Trainable params: 22,208,077
# Non-trainable params: 3,842
# __________________________________________________________________________________________________

# %%
def unet(inputs=Input((512, 128, 1))):
    conv1 = Conv2D(16, 5, strides=2, padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = LeakyReLU(alpha=0.2)(conv1)

    conv2 = Conv2D(32, 5, strides=2, padding='same')(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = LeakyReLU(alpha=0.2)(conv2)

    conv3 = Conv2D(64, 5, strides=2, padding='same')(conv2)
    conv3 = BatchNormalization()(conv3)
    conv3 = LeakyReLU(alpha=0.2)(conv3)

    conv4 = Conv2D(128, 5, strides=2, padding='same')(conv3)
    conv4 = BatchNormalization()(conv4)
    conv4 = LeakyReLU(alpha=0.2)(conv4)

    conv5 = Conv2D(256, 5, strides=2, padding='same')(conv4)
    conv5 = BatchNormalization()(conv5)
    conv5 = LeakyReLU(alpha=0.2)(conv5)

    conv6 = Conv2D(512, 5, strides=2, padding='same')(conv5)
    conv6 = BatchNormalization()(conv6)
    conv6 = LeakyReLU(alpha=0.2)(conv6)

    deconv7 = Deconv2D(256, 5, strides=2, padding='same')(conv6)
    deconv7 = BatchNormalization()(deconv7)
    deconv7 = Dropout(0.5)(deconv7)
    deconv7 = Activation('relu')(deconv7)

    deconv8 = Concatenate(axis=3)([deconv7, conv5])
    deconv8 = Deconv2D(128, 5, strides=2, padding='same')(deconv8)
    deconv8 = BatchNormalization()(deconv8)
    deconv8 = Dropout(0.5)(deconv8)
    deconv8 = Activation('relu')(deconv8)

    deconv9 = Concatenate(axis=3)([deconv8, conv4])
    deconv9 = Deconv2D(64, 5, strides=2, padding='same')(deconv9)
    deconv9 = BatchNormalization()(deconv9)
    deconv9 = Dropout(0.5)(deconv9)
    deconv9 = Activation('relu')(deconv9)

    deconv10 = Concatenate(axis=3)([deconv9, conv3])
    deconv10 = Deconv2D(32, 5, strides=2, padding='same')(deconv10)
    deconv10 = BatchNormalization()(deconv10)
    deconv10 = Activation('relu')(deconv10)

    deconv11 = Concatenate(axis=3)([deconv10, conv2])
    deconv11 = Deconv2D(16, 5, strides=2, padding='same')(deconv11)
    deconv11 = BatchNormalization()(deconv11)
    deconv11 = Activation('relu')(deconv11)

    deconv12 = Concatenate(axis=3)([deconv11, conv1])
    deconv12 = Deconv2D(1, 5, strides=2, padding='same')(deconv12)
    deconv12 = Activation('relu')(deconv12)

    model = Model(inputs=inputs, outputs=deconv12)
    model.summary()
    return model

# %%
unet()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 64, 16)  416         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256, 64, 16)  64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 256, 64, 16)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 128, 32, 32)  12832       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 32, 32)  128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 128, 32, 32)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 16, 64)   51264       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 16, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 64, 16, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 8, 128)   204928      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 8, 128)   512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 32, 8, 128)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 4, 256)   819456      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 4, 256)   1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 16, 4, 256)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 2, 512)    3277312     leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 2, 512)    2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 8, 2, 512)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 16, 4, 256)   3277056     leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 4, 256)   1024        conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 4, 256)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 4, 256)   0           dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 4, 512)   0           activation_6[0][0]
#                                                                  leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 32, 8, 128)   1638528     concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 8, 128)   512         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 8, 128)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 8, 128)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 8, 256)   0           activation_7[0][0]
#                                                                  leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 64, 16, 64)   409664      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 16, 64)   256         conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 16, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 16, 64)   0           dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 16, 128)  0           activation_8[0][0]
#                                                                  leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 128, 32, 32)  102432      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 128, 32, 32)  128         conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 32, 32)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 32, 64)  0           activation_9[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 256, 64, 16)  25616       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256, 64, 16)  64          conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 256, 64, 16)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 256, 64, 32)  0           activation_10[0][0]
#                                                                  leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 512, 128, 1)  801         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 512, 128, 1)  0           conv2d_transpose_11[0][0]
# ==================================================================================================
# Total params: 9,826,321
# Trainable params: 9,823,313
# Non-trainable params: 3,008
# __________________________________________________________________________________________________
